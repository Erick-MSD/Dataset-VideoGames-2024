# %%
import matplotlib.pyplot as plt

x = [2,3,4,5]
y = [5,7,6,8]

plt.plot(x,y,marker='o')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.title('Grafica')

plt.xlim(left=0)
plt.ylim(bottom=0)
plt.show()
